# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Grocery-Store-Sales.xlsx')

# %%
df.head()
# Out:
#    Store  Sales per Square Foot ($)  Size of Store (in Sq. Ft.)  \
# 0      1                        837                       64796
# 1      2                        748                       74179
# 2      3                        744                       70298
# 3      4                        853                       63367
# 4      5                        839                       74412
#
#    Advertising Dollars  Number of Products Offered in Store
# 0                22000                                32920
# 1                58000                                25034
# 2                58000                                23989
# 3                56000                                31095
# 4                67000                                35055

# %%
df.describe()
# Out:
#            Store  Sales per Square Foot ($)  Size of Store (in Sq. Ft.)  \
# count  70.000000                  70.000000                   70.000000
# mean   35.500000                 838.500000                63447.228571
# std    20.351085                  64.558647                 7648.784559
# min     1.000000                 705.000000                51980.000000
# 25%    18.250000                 801.250000                56966.500000
# 50%    35.500000                 840.500000                62239.500000
# 75%    52.750000                 868.750000                70129.750000
# max    70.000000                 989.000000                79819.000000
#
#        Advertising Dollars  Number of Products Offered in Store
# count            70.000000                            70.000000
# mean          48842.857143                         30839.328571
# std           15887.864035                          5444.776571
# ...
